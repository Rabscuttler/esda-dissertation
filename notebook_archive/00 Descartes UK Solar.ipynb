# %% [markdown]
# # Examine Descartes Labs & Lucas's GB polygons

# %%
# Setup
import pandas as pd
import numpy as np
import datetime as dt

import glob
import os
from pathlib import Path
import itertools

import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import colour

from matplotlib import cm
from matplotlib.colors import ListedColormap, LinearSegmentedColormap
# https://matplotlib.org/3.1.0/tutorials/colors/colormap-manipulation.html

from shapely.geometry import Polygon
import geopandas as gpd
import pyproj # Do I need this when I can use geopandas.crs ??
import folium
import affine

from tqdm import tqdm # Progress bar stuff cos progress bars are good
tqdm.pandas() # now can use progress_apply instead of apply

import pickle # Pickle stuff, cos pickling is good

# Styles
pd.set_option('display.float_format', lambda x: '%.2f' % x) # pandas
np.set_printoptions(precision=5, suppress=True) # numpy

pd.set_option('display.max_columns', 100)
pd.set_option('display.max_rows', 100)

# seaborn plotting style
sns.set(style='ticks', context='poster')

# %%
pv = gpd.read_file('data/descartes_GB_v1.1.geojson')

# %%
pv.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 6837 entries, 0 to 6836
# Data columns (total 8 columns):
# confidence           6837 non-null object
# install_date         6837 non-null object
# install_date_ints    6837 non-null object
# S2_ids_0             6837 non-null object
# SPOT_ids_0           6837 non-null object
# area                 6837 non-null float64
# SPOT_ids_1           52 non-null object
# geometry             6837 non-null object
# dtypes: float64(1), object(7)
# memory usage: 427.4+ KB

# %%
m = folium.Map([53.751, -1.9950], zoom_start=6, tiles='cartodbpositron', attr='Map')
folium.GeoJson(pv[:200]).add_to(m)

# Check against OSM layers
folium.TileLayer('openstreetmap').add_to(m)

folium.LayerControl().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## TODO check against OSM
